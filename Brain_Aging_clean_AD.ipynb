# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, KFold
from sklearn.model_selection import StratifiedKFold

from sklearn.preprocessing import MinMaxScaler
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import shap
from sklearn.linear_model import LinearRegression
import seaborn as sns
import os
from joblib import dump, load
import pickle

from nilearn import plotting
import statsmodels.api as sm
from sklearn.model_selection import StratifiedShuffleSplit
from scipy.stats import linregress
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
path=  'C:/Users/felipe/Documents/Brain/'
import sys
sys.path.append(path) 
path_=  'C:/Users/felipe/Documents/Brain/Brain_Age/Models/'
import sys
sys.path.append(path_)

# %%
file_name = 'dataframe_alpha.xlsx'
file_path_Alpha = f"{path}{file_name}"
df_Alpha = pd.read_excel(file_path_Alpha)

# %%
df_Alpha
# Out:
#       Unnamed: 0   Age  Alpha2_canon_EPP_HPC_left  Alpha2_canon_EPP_HPC_right  \
# 0              0  33.0               8.116489e-03                7.831277e-03
# 1              1  39.0               6.847430e-08                6.847430e-08
# 2              2  26.0               6.847430e-08                6.847430e-08
# 3              3  57.0               1.464674e-02                1.347051e-02
# 4              4  32.0               4.464840e-03                3.429442e-03
# ...          ...   ...                        ...                         ...
# 1489        1544  48.0               7.818791e-03                8.175485e-03
# 1490        1546  57.0               6.954099e-03                6.618436e-03
# 1491        1548  57.0               1.078376e-02                1.076256e-02
# 1492        1549  69.0               1.143728e-02                1.117073e-02
# 1493        1550  64.0               7.080235e-03                7.668745e-03
#
#       Alpha2_canon_EPP_PARIET_left  Alpha2_canon_EPP_PARIET_right  \
# 0                     7.685130e-03                   6.256429e-03
# 1                     6.847430e-08                   6.847430e-08
# 2                     6.847430e-08                   6.847430e-08
# 3                     1.307290e-02                   1.382201e-02
# 4                     5.261400e-03                   4.029530e-03
# ...                            ...                            ...
# 1489                  7.330004e-03                   9.785953e-03
# 1490                  5.140992e-03                   5.684756e-03
# 1491                  7.001387e-03                   7.620053e-03
# 1492                  9.037550e-03                   1.152258e-02
# 1493                  6.359751e-03                   7.852609e-03
#
#       Alpha2_canon_EPP_OCC_left  Alpha2_canon_EPP_OCC_right  \
# 0                  6.910771e-03                8.989653e-03
# 1                  6.847430e-08                6.847430e-08
# 2                  6.847430e-08                6.847430e-08
# 3                  2.193269e-02                1.779899e-02
# 4                  6.252499e-03                6.697983e-03
# ...                         ...                         ...
# 1489               9.442898e-03                9.162112e-03
# 1490               7.440296e-03                6.691578e-03
# 1491               8.772741e-03                8.320177e-03
# 1492               9.255336e-03                9.589549e-03
# 1493               8.180268e-03                9.289159e-03
#
#       Alpha2_canon_RPD_HPC_left  Alpha2_canon_RPD_HPC_right  ...  \
# 0                  1.159498e-03                1.118754e-03  ...
# 1                  9.782043e-09                9.782043e-09  ...
# 2                  9.782043e-09                9.782043e-09  ...
# 3                  2.092391e-03                1.924358e-03  ...
# 4                  6.378343e-04                4.899203e-04  ...
# ...                         ...                         ...  ...
# 1489               1.116970e-03                1.167926e-03  ...
# 1490               9.934427e-04                9.454908e-04  ...
# 1491               1.540538e-03                1.537509e-03  ...
# 1492               1.633898e-03                1.595818e-03  ...
# 1493               1.011462e-03                1.095535e-03  ...
#
#       IAF_MFG_left  IAF_MFG_right  IAF_SFG_left  IAF_SFG_right  IAF_HPC_left  \
# 0            8.875          8.750        8.9375         8.8750      9.000000
# 1            8.500          8.500        8.5000         8.5000      8.500000
# 2            8.500          8.500        8.5000         8.5000      8.500000
# 3           11.375         11.625       11.6875        11.6875     11.500000
# 4           10.000         10.250       10.0625        10.0625     10.083333
# ...            ...            ...           ...            ...           ...
# 1489         9.875          8.250        8.3125         9.6250      9.583333
# 1490         8.000         10.000        8.0000         8.5625      8.000000
# 1491         9.125          8.500        9.2500         9.0625      8.666667
# 1492         8.000          8.000        9.0625         9.0000      9.333333
# 1493         8.625          9.500        8.0000         9.1875      8.500000
#
#       IAF_HPC_right  IAF_INS_left  IAF_INS_right  IAF_OCC_left  IAF_OCC_right
# 0          8.916667           9.0          8.625      8.833333       8.791667
# 1          8.500000           8.5          8.500      8.500000       8.500000
# 2          8.500000           8.5          8.500      8.500000       8.500000
# 3         11.666667          11.5         11.625     11.375000      11.500000
# 4          9.833333          10.0         10.375     10.125000      10.166667
# ...             ...           ...            ...           ...            ...
# 1489      11.750000           9.5         10.750      9.750000       9.833333
# 1490      12.000000           8.0         10.000      8.000000       9.041667
# 1491       8.583333           9.0          9.000      8.958333       8.000000
# 1492       8.583333           8.5          8.625      9.916667       9.708333
# 1493       8.833333           8.0          9.625      9.166667       8.833333
#
# [1494 rows x 74 columns]

# %%
# Seleccionamos todas las columnas a partir de la tercera (índice 2)
metricas = df_Alpha.columns[2:]

# Convertimos los nombres de las columnas a una lista
lista_metricas = list(metricas)

print(lista_metricas)
# Out:
# ['Alpha2_canon_EPP_HPC_left', 'Alpha2_canon_EPP_HPC_right', 'Alpha2_canon_EPP_PARIET_left', 'Alpha2_canon_EPP_PARIET_right', 'Alpha2_canon_EPP_OCC_left', 'Alpha2_canon_EPP_OCC_right', 'Alpha2_canon_RPD_HPC_left', 'Alpha2_canon_RPD_HPC_right', 'Alpha2_canon_RPD_CING_left', 'Alpha2_canon_RPD_CING_right', 'Alpha2_canon_RPD_PARIET_left', 'Alpha2_canon_RPD_PARIET_right', 'Alpha2_canon_RPD_OCC_left', 'Alpha2_canon_RPD_OCC_right', 'High_subj_spec_EPP_HPC_left', 'High_subj_spec_EPP_HPC_right', 'High_subj_spec_EPP_CING_left', 'High_subj_spec_EPP_CING_right', 'High_subj_spec_EPP_PARIET_left', 'High_subj_spec_EPP_PARIET_right', 'High_subj_spec_EPP_OCC_left', 'High_subj_spec_EPP_OCC_right', 'High_subj_spec_RPD_HPC_left', 'High_subj_spec_RPD_HPC_right', 'High_subj_spec_RPD_CING_left', 'High_subj_spec_RPD_CING_right', 'High_subj_spec_RPD_PARIET_left', 'High_subj_spec_RPD_PARIET_right', 'High_subj_spec_RPD_OCC_left', 'High_subj_spec_RPD_OCC_right', 'Low_subj_spec_EPP_HPC_left', 'Low_subj_spec_EPP_HPC_right', 'Low_subj_spec_EPP_CING_left', 'Low_subj_spec_EPP_CING_right', 'Low_subj_spec_EPP_PARIET_left', 'Low_subj_spec_EPP_PARIET_right', 'Low_subj_spec_EPP_OCC_left', 'Low_subj_spec_EPP_OCC_right', 'Low_subj_spec_RPD_HPC_left', 'Low_subj_spec_RPD_HPC_right', 'Low_subj_spec_RPD_CING_left', 'Low_subj_spec_RPD_CING_right', 'Low_subj_spec_RPD_PARIET_left', 'Low_subj_spec_RPD_PARIET_right', 'Low_subj_spec_RPD_OCC_left', 'Low_subj_spec_RPD_OCC_right', 'TF_ORB_left', 'TF_ORB_right', 'TF_IFG_left', 'TF_IFG_right', 'TF_MFG_left', 'TF_MFG_right', 'TF_SFG_left', 'TF_SFG_right', 'TF_HPC_left', 'TF_HPC_right', 'TF_INS_left', 'TF_INS_right', 'IAF_ORB_left', 'IAF_ORB_right', 'IAF_IFG_left', 'IAF_IFG_right', 'IAF_MFG_left', 'IAF_MFG_right', 'IAF_SFG_left', 'IAF_SFG_right', 'IAF_HPC_left', 'IAF_HPC_right', 'IAF_INS_left', 'IAF_INS_right', 'IAF_OCC_left', 'IAF_OCC_right']

# %%
significant_features = ['Alpha2_canon_EPP_HPC_left', 'Alpha2_canon_EPP_HPC_right', 'Alpha2_canon_EPP_PARIET_left', 'Alpha2_canon_EPP_PARIET_right', 'Alpha2_canon_EPP_OCC_left', 'Alpha2_canon_EPP_OCC_right', 'Alpha2_canon_RPD_HPC_left', 'Alpha2_canon_RPD_HPC_right', 'Alpha2_canon_RPD_CING_left', 'Alpha2_canon_RPD_CING_right', 'Alpha2_canon_RPD_PARIET_left', 'Alpha2_canon_RPD_PARIET_right', 'Alpha2_canon_RPD_OCC_left', 'Alpha2_canon_RPD_OCC_right', 'High_subj_spec_EPP_HPC_left', 'High_subj_spec_EPP_HPC_right', 'High_subj_spec_EPP_CING_left', 'High_subj_spec_EPP_CING_right', 'High_subj_spec_EPP_PARIET_left', 'High_subj_spec_EPP_PARIET_right', 'High_subj_spec_EPP_OCC_left', 'High_subj_spec_EPP_OCC_right', 'High_subj_spec_RPD_HPC_left', 'High_subj_spec_RPD_HPC_right', 'High_subj_spec_RPD_CING_left', 'High_subj_spec_RPD_CING_right', 'High_subj_spec_RPD_PARIET_left', 'High_subj_spec_RPD_PARIET_right', 'High_subj_spec_RPD_OCC_left', 'High_subj_spec_RPD_OCC_right', 'Low_subj_spec_EPP_HPC_right', 'Low_subj_spec_EPP_PARIET_left', 'Low_subj_spec_EPP_PARIET_right', 'Low_subj_spec_EPP_OCC_left', 'Low_subj_spec_EPP_OCC_right', 'Low_subj_spec_RPD_HPC_left', 'Low_subj_spec_RPD_HPC_right', 'Low_subj_spec_RPD_CING_left', 'Low_subj_spec_RPD_CING_right', 'Low_subj_spec_RPD_PARIET_left', 'Low_subj_spec_RPD_PARIET_right', 'Low_subj_spec_RPD_OCC_left', 'Low_subj_spec_RPD_OCC_right', 'TF_ORB_left', 'TF_ORB_right', 'TF_IFG_left', 'TF_IFG_right', 'TF_MFG_left', 'TF_MFG_right', 'TF_SFG_left', 'TF_SFG_right', 'TF_HPC_left', 'TF_HPC_right', 'TF_INS_left', 'TF_INS_right', 'IAF_SFG_left', 'IAF_SFG_right', 'IAF_HPC_left', 'IAF_HPC_right', 'IAF_INS_left', 'IAF_OCC_left', 'IAF_OCC_right']

# %%
file_path_CN = f'{path}Brain_Aging/CN_freq.xlsx'
file_path_AD = f'{path}Brain_Aging/AD_freq.xlsx'

# %%
df_CN = pd.read_excel(file_path_CN)
df_AD = pd.read_excel(file_path_AD)

# Agregar columna de ID en df_CN
df_CN['ID-unique'] = range(len(df_CN))

# Agregar columna de ID en df_AD
df_AD['ID-unique'] = range(len(df_AD))

# %%
#df_CN.to_excel(file_path_CN, index=False)
#df_AD.to_excel(file_path_AD, index=False)

# %%
df_CN_filtrado = df_CN[(df_CN['Age'] >= 60) & (df_CN['Age'] <= 90)].reset_index(drop=True)
df_AD_filtrado = df_AD[(df_AD['Age'] >= 60) & (df_AD['Age'] <= 90)].reset_index(drop=True)

# %%
X_CN = df_CN_filtrado[significant_features]
y_CN = df_CN_filtrado["Age"]
ID_CN = df_CN_filtrado["ID-unique"]

# %%
X_CN
# Out:
#      Alpha2_canon_EPP_HPC_left  Alpha2_canon_EPP_HPC_right  \
# 0                     0.008997                    0.008343
# 1                     0.007660                    0.003629
# 2                     0.008820                    0.008595
# 3                     0.008578                    0.007068
# 4                     0.006096                    0.008411
# ..                         ...                         ...
# 516                   0.007580                    0.008656
# 517                   0.010478                    0.007816
# 518                   0.007669                    0.008426
# 519                   0.011437                    0.011171
# 520                   0.007080                    0.007669
#
#      Alpha2_canon_EPP_PARIET_left  Alpha2_canon_EPP_PARIET_right  \
# 0                        0.005692                       0.009014
# 1                        0.005438                       0.005726
# 2                        0.011113                       0.008620
# 3                        0.006751                       0.008861
# 4                        0.006677                       0.009440
# ..                            ...                            ...
# 516                      0.007308                       0.009685
# 517                      0.009692                       0.009971
# 518                      0.007006                       0.008673
# 519                      0.009038                       0.011523
# 520                      0.006360                       0.007853
#
#      Alpha2_canon_EPP_OCC_left  Alpha2_canon_EPP_OCC_right  \
# 0                     0.006511                    0.008794
# 1                     0.003804                    0.003142
# 2                     0.009592                    0.009236
# 3                     0.006848                    0.006815
# 4                     0.007105                    0.010014
# ..                         ...                         ...
# 516                   0.006904                    0.007596
# 517                   0.010166                    0.008538
# 518                   0.007803                    0.009830
# 519                   0.009255                    0.009590
# 520                   0.008180                    0.009289
#
#      Alpha2_canon_RPD_HPC_left  Alpha2_canon_RPD_HPC_right  \
# 0                     0.001285                    0.001192
# 1                     0.001094                    0.000518
# 2                     0.001260                    0.001228
# 3                     0.001225                    0.001010
# 4                     0.000871                    0.001202
# ..                         ...                         ...
# 516                   0.001083                    0.001237
# 517                   0.001497                    0.001117
# 518                   0.001096                    0.001204
# 519                   0.001634                    0.001596
# 520                   0.001011                    0.001096
#
#      Alpha2_canon_RPD_CING_left  Alpha2_canon_RPD_CING_right  ...  \
# 0                      0.001011                     0.000862  ...
# 1                      0.000701                     0.000610  ...
# 2                      0.001183                     0.001087  ...
# 3                      0.001039                     0.000962  ...
# 4                      0.000993                     0.001086  ...
# ..                          ...                          ...  ...
# 516                    0.001008                     0.001073  ...
# 517                    0.001078                     0.001068  ...
# 518                    0.000931                     0.001048  ...
# 519                    0.001084                     0.001123  ...
# 520                    0.000967                     0.001083  ...
#
#      TF_HPC_right  TF_INS_left  TF_INS_right  IAF_SFG_left  IAF_SFG_right  \
# 0        7.000000        7.000           7.0        8.5000         9.3125
# 1        7.000000        7.000           7.0        8.8750         8.9375
# 2        7.000000        7.000           7.0        8.8125         8.8125
# 3        7.000000        7.250           7.0        8.1875         8.2500
# 4        7.000000        7.000           7.0        8.1875         8.1250
# ..            ...          ...           ...           ...            ...
# 516      7.000000        7.000           7.0        9.0000         9.0625
# 517      7.666667        8.000           7.5        8.0000         8.8125
# 518      7.750000        7.125           8.0        8.0625         8.0000
# 519      7.000000        8.000           7.0        9.0625         9.0000
# 520      8.000000        8.000           7.5        8.0000         9.1875
#
#      IAF_HPC_left  IAF_HPC_right  IAF_INS_left  IAF_OCC_left  IAF_OCC_right
# 0        9.583333       8.250000         9.375      8.875000       8.666667
# 1        9.000000       9.000000         8.875      8.916667       8.791667
# 2        8.500000       8.833333         8.750      8.791667       8.791667
# 3        8.083333       8.666667         8.500      8.000000       8.000000
# 4        9.000000       9.583333         8.750     10.375000      10.625000
# ..            ...            ...           ...           ...            ...
# 516      8.583333       8.916667         8.750      8.583333       8.625000
# 517      9.000000       8.000000         8.000      8.250000       8.166667
# 518      9.000000       9.166667         8.375      8.666667       9.041667
# 519      9.333333       8.583333         8.500      9.916667       9.708333
# 520      8.500000       8.833333         8.000      9.166667       8.833333
#
# [521 rows x 62 columns]
