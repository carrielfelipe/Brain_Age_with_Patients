# %%
import pandas as pd

# Ruta principal
path = r'C:/Users/felipe/Documents/Brain/Brain_Age_metricas/Freq/'

df_CN = pd.read_excel(f"{path}CN/frecuency_jhos_.xlsx")


# Leer archivos y asignar a variables
df_AD_arg = pd.read_excel(f"{path}AD/AD_ARG_freq.xlsx")
df_AD_col = pd.read_excel(f"{path}AD/AD_Col_freq.xlsx")
df_AD_bra = pd.read_excel(f"{path}AD/Bra_USP_AD_processed_SourceTransformation_ODQ_metrics.xlsx")
df_AD_ch = pd.read_excel(f"{path}AD/CH_freq.xlsx")
df_AD_tur = pd.read_excel(f"{path}AD/Tur_IUEFM_AD_processed_SourceTransformation_ODQ_metrics.xlsx")

df_FTD_arg = pd.read_excel(f"{path}FTD/ARG_FTD_freq.xlsx")
df_FTD_ch = pd.read_excel(f"{path}FTD/CH_FTD_freq.xlsx")
df_FTD_col = pd.read_excel(f"{path}FTD/Tak_Col_Bog_processed_SourceTransformation_ODQ_metrics.xlsx")

df_MCI_col = pd.read_excel(f"{path}MCI/Col_MCI_processed_SourceTransformation_ODQ_metrics.xlsx")
df_MCI_tur = pd.read_excel(f"{path}MCI/Tur_IUEFM_MCI_processed_SourceTransformation_ODQ_metrics.xlsx")

df_PD_arg = pd.read_excel(f"{path}PD/ARG_F17_PD_processed_SourceTransformation_ODQ_metrics.xlsx")
df_PD_chile = pd.read_excel(f"{path}PD/Chile_Takeda_new_PD_SourceTransformation_PD_Frecuency_metrics_ODQ_metrics.xlsx")
df_PD_ch_f17 = pd.read_excel(f"{path}PD/CH_F17_Frecuency_metrics_ODQ_metrics.xlsx")
df_PD_ch_new2 = pd.read_excel(f"{path}PD/CH_Tak_new2_PD_processed_SourceTransformation_ODQ_metrics.xlsx")
df_PD_ch_new3 = pd.read_excel(f"{path}PD/CH_Tak_new3_PD_processed_SourceTransformation_ODQ_metrics.xlsx")

# %%
# Agrupar DataFrames por enfermedad
dfs_AD = [df_AD_arg, df_AD_col, df_AD_bra, df_AD_ch, df_AD_tur]
dfs_FTD = [df_FTD_arg, df_FTD_ch, df_FTD_col]
dfs_MCI = [df_MCI_col, df_MCI_tur]
dfs_PD = [df_PD_arg, df_PD_chile, df_PD_ch_f17, df_PD_ch_new2, df_PD_ch_new3]

# %%
df_AD = pd.concat(dfs_AD, ignore_index=True)
df_FTD = pd.concat(dfs_FTD, ignore_index=True)
df_MCI = pd.concat(dfs_MCI, ignore_index=True)
df_PD = pd.concat(dfs_PD, ignore_index=True)

df_CN['ID-unique'] = range(len(df_CN))
df_AD['ID-unique'] = range(len(df_AD))
df_FTD['ID-unique'] = range(len(df_FTD))
df_MCI['ID-unique'] = range(len(df_MCI))
df_PD['ID-unique'] = range(len(df_PD))

# %%
path_ = r'C:/Users/felipe/Documents/Brain/'
file_path_CN = f'{path_}Brain_Aging/CN_freq.xlsx'
file_path_AD = f'{path_}Brain_Aging/AD_freq.xlsx'
file_path_FTD = f'{path_}Brain_Aging/FTD_freq.xlsx'
file_path_MCI = f'{path_}Brain_Aging/MCI_freq.xlsx'
file_path_PD = f'{path_}Brain_Aging/PD_freq.xlsx'

# %%
#df_CN.to_excel(file_path_CN, index=False)
#df_AD.to_excel(file_path_AD, index=False)
#df_FTD.to_excel(file_path_FTD, index=False)
#df_MCI.to_excel(file_path_MCI, index=False)
#df_PD.to_excel(file_path_PD, index=False)

# %%
df_CN = pd.read_excel(file_path_CN)
df_AD = pd.read_excel(file_path_AD)
df_FTD = pd.read_excel(file_path_FTD)
df_MCI = pd.read_excel(file_path_MCI)
df_PD = pd.read_excel(file_path_PD)

df_CN_filtrado = df_CN[(df_CN['Age'] >= 40) & (df_CN['Age'] <= 80)].reset_index(drop=True)
df_AD_filtrado = df_AD[(df_AD['Age'] >= 40) & (df_AD['Age'] <= 80)].reset_index(drop=True)
df_FTD_filtrado = df_FTD[(df_FTD['Age'] >= 40) & (df_FTD['Age'] <= 80)].reset_index(drop=True)
df_MCI_filtrado = df_MCI[(df_MCI['Age'] >= 40) & (df_MCI['Age'] <= 80)].reset_index(drop=True)
df_PD_filtrado = df_PD[(df_PD['Age'] >= 40) & (df_PD['Age'] <= 80)].reset_index(drop=True)

# %%
df_PD['Group'] = 'PD'
df_MCI['Group'] = 'MCI'

# %%
file_name = 'dataframe_alpha.xlsx'
file_path_Alpha = f"{path_}{file_name}"
df_Alpha = pd.read_excel(file_path_Alpha)
# Seleccionamos todas las columnas a partir de la tercera (índice 2)
metricas = df_Alpha.columns[2:]

# Convertimos los nombres de las columnas a una lista
lista_metricas = list(metricas)

print(lista_metricas)
# Out:
# ['Alpha2_canon_EPP_HPC_left', 'Alpha2_canon_EPP_HPC_right', 'Alpha2_canon_EPP_PARIET_left', 'Alpha2_canon_EPP_PARIET_right', 'Alpha2_canon_EPP_OCC_left', 'Alpha2_canon_EPP_OCC_right', 'Alpha2_canon_RPD_HPC_left', 'Alpha2_canon_RPD_HPC_right', 'Alpha2_canon_RPD_CING_left', 'Alpha2_canon_RPD_CING_right', 'Alpha2_canon_RPD_PARIET_left', 'Alpha2_canon_RPD_PARIET_right', 'Alpha2_canon_RPD_OCC_left', 'Alpha2_canon_RPD_OCC_right', 'High_subj_spec_EPP_HPC_left', 'High_subj_spec_EPP_HPC_right', 'High_subj_spec_EPP_CING_left', 'High_subj_spec_EPP_CING_right', 'High_subj_spec_EPP_PARIET_left', 'High_subj_spec_EPP_PARIET_right', 'High_subj_spec_EPP_OCC_left', 'High_subj_spec_EPP_OCC_right', 'High_subj_spec_RPD_HPC_left', 'High_subj_spec_RPD_HPC_right', 'High_subj_spec_RPD_CING_left', 'High_subj_spec_RPD_CING_right', 'High_subj_spec_RPD_PARIET_left', 'High_subj_spec_RPD_PARIET_right', 'High_subj_spec_RPD_OCC_left', 'High_subj_spec_RPD_OCC_right', 'Low_subj_spec_EPP_HPC_left', 'Low_subj_spec_EPP_H
# ...

# %%
significant_features=['Alpha2_canon_EPP_HPC_left', 'Alpha2_canon_EPP_HPC_right', 'Alpha2_canon_EPP_PARIET_left', 'Alpha2_canon_EPP_PARIET_right', 'Alpha2_canon_EPP_OCC_left', 'Alpha2_canon_EPP_OCC_right', 'Alpha2_canon_RPD_HPC_left', 'Alpha2_canon_RPD_HPC_right', 'Alpha2_canon_RPD_CING_left', 'Alpha2_canon_RPD_CING_right', 'Alpha2_canon_RPD_PARIET_left', 'Alpha2_canon_RPD_PARIET_right', 'Alpha2_canon_RPD_OCC_left', 'Alpha2_canon_RPD_OCC_right', 'High_subj_spec_EPP_HPC_left', 'High_subj_spec_EPP_HPC_right', 'High_subj_spec_EPP_CING_left', 'High_subj_spec_EPP_CING_right', 'High_subj_spec_EPP_PARIET_left', 'High_subj_spec_EPP_PARIET_right', 'High_subj_spec_EPP_OCC_left', 'High_subj_spec_EPP_OCC_right', 'High_subj_spec_RPD_HPC_left', 'High_subj_spec_RPD_HPC_right', 'High_subj_spec_RPD_CING_left', 'High_subj_spec_RPD_CING_right', 'High_subj_spec_RPD_PARIET_left', 'High_subj_spec_RPD_PARIET_right', 'High_subj_spec_RPD_OCC_left', 'High_subj_spec_RPD_OCC_right', 'Low_subj_spec_EPP_HPC_left', 'Low_subj_spec_EPP_HPC_right', 'Low_subj_spec_EPP_CING_left', 'Low_subj_spec_EPP_CING_right', 'Low_subj_spec_EPP_PARIET_left', 'Low_subj_spec_EPP_PARIET_right', 'Low_subj_spec_EPP_OCC_left', 'Low_subj_spec_EPP_OCC_right', 'Low_subj_spec_RPD_HPC_left', 'Low_subj_spec_RPD_HPC_right', 'Low_subj_spec_RPD_CING_left', 'Low_subj_spec_RPD_CING_right', 'Low_subj_spec_RPD_PARIET_left', 'Low_subj_spec_RPD_PARIET_right', 'Low_subj_spec_RPD_OCC_left', 'Low_subj_spec_RPD_OCC_right', 'TF_ORB_left', 'TF_ORB_right', 'TF_IFG_left', 'TF_IFG_right', 'TF_MFG_left', 'TF_MFG_right', 'TF_SFG_left', 'TF_SFG_right', 'TF_HPC_left', 'TF_HPC_right', 'TF_INS_left', 'TF_INS_right', 'IAF_ORB_left', 'IAF_ORB_right', 'IAF_IFG_left', 'IAF_IFG_right', 'IAF_MFG_left', 'IAF_MFG_right', 'IAF_SFG_left', 'IAF_SFG_right', 'IAF_HPC_left', 'IAF_HPC_right', 'IAF_INS_left', 'IAF_INS_right', 'IAF_OCC_left', 'IAF_OCC_right']

# %%
X_CN = df_CN_filtrado[significant_features]
y_CN = df_CN_filtrado["Age"]
ID_CN = df_CN_filtrado["ID-unique"]

X_AD = df_AD_filtrado[significant_features]
y_AD = df_AD_filtrado["Age"]
ID_AD = df_AD_filtrado["ID-unique"]

X_FTD = df_FTD_filtrado[significant_features]
y_FTD = df_FTD_filtrado["Age"]
ID_FTD = df_FTD_filtrado["ID-unique"]

X_MCI = df_MCI_filtrado[significant_features]
y_MCI = df_MCI_filtrado["Age"]
ID_MCI = df_MCI_filtrado["ID-unique"]

X_PD = df_PD_filtrado[significant_features]
y_PD = df_PD_filtrado["Age"]
ID_PD = df_PD_filtrado["ID-unique"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import Ridge, Lasso

scaler = MinMaxScaler((0.05,0.95))
#scaler = StandardScaler()

scaler.fit(X_CN)

X_CN_scaled = scaler.transform(X_CN)
X_AD_scaled = scaler.transform(X_AD)
X_FTD_scaled = scaler.transform(X_FTD)
X_MCI_scaled = scaler.transform(X_MCI)
X_PD_scaled = scaler.transform(X_PD)

X_CN_train, X_CN_test, y_CN_train, y_CN_test = train_test_split(X_CN_scaled, y_CN, test_size=0.2, random_state=42)

#model = LinearRegression()
#model.fit(X_CN_train, y_CN_train)

model = Lasso(alpha=0.1)
model.fit(X_CN_train, y_CN_train)

y_pred_CN_test = model.predict(X_CN_test)

mse_CN_test = mean_squared_error(y_CN_test, y_pred_CN_test)
r2_CN_test = r2_score(y_CN_test, y_pred_CN_test)
print(f"Resultados en CN (test): MSE = {mse_CN_test}, R2 = {r2_CN_test}")

y_pred_AD = model.predict(X_AD_scaled)

mse_AD = mean_squared_error(y_AD, y_pred_AD)
r2_AD = r2_score(y_AD, y_pred_AD)
print(f"Resultados en AD: MSE = {mse_AD}, R2 = {r2_AD}")

residuals_AD = y_AD - y_pred_AD  # Calcular los residuales (errores)
print(f"Residuals en AD: {residuals_AD}")

# Para FTD
y_pred_FTD = model.predict(X_FTD_scaled)

mse_FTD = mean_squared_error(y_FTD, y_pred_FTD)
r2_FTD = r2_score(y_FTD, y_pred_FTD)
print(f"Resultados en FTD: MSE = {mse_FTD}, R2 = {r2_FTD}")

residuals_FTD = y_FTD - y_pred_FTD  # Calcular los residuales (errores)
print(f"Residuals en FTD: {residuals_FTD}")

# Para MCI
y_pred_MCI = model.predict(X_MCI_scaled)

mse_MCI = mean_squared_error(y_MCI, y_pred_MCI)
r2_MCI = r2_score(y_MCI, y_pred_MCI)
print(f"Resultados en MCI: MSE = {mse_MCI}, R2 = {r2_MCI}")

residuals_MCI = y_MCI - y_pred_MCI  # Calcular los residuales (errores)
print(f"Residuals en MCI: {residuals_MCI}")

# Para PD
y_pred_PD = model.predict(X_PD_scaled)

mse_PD = mean_squared_error(y_PD, y_pred_PD)
r2_PD = r2_score(y_PD, y_pred_PD)
print(f"Resultados en PD: MSE = {mse_PD}, R2 = {r2_PD}")

residuals_PD = y_PD - y_pred_PD  # Calcular los residuales (errores)
print(f"Residuals en PD: {residuals_PD}")
# Out:
# Resultados en CN (test): MSE = 99.74703871022987, R2 = 0.01981113885055097
# Resultados en AD: MSE = 153.16314000659239, R2 = -1.9666623425289704
# Residuals en AD: 0       8.480051
# 1       7.990694
# 2      25.203745
# 3       8.987558
# 4       7.301444
#          ...
# 300    10.792929
# 301     6.765094
# 302     8.787623
# 303     2.542853
# 304    17.098431
# Name: Age, Length: 305, dtype: float64
# Resultados en FTD: MSE = 92.12663907633552, R2 = -0.23690517829464364
# Residuals en FTD: 0     13.660125
# 1      0.704103
# 2     14.738388
# 3      3.398732
# 4      4.242722
# 5      3.986880
# 6      9.911240
# 7    -26.401466
# 8     20.782576
# 9      7.761411
# 10    -2.247566
# 11    -8.860133
# 12    -3.010740
# 13     3.323954
# 14    20.567006
# 15    -5.855036
# 16    15.317411
# 17    13.293570
# 18    16.567006
# 19    12.567006
# 20    -6.341284
# 21     2.051681
# 22     1.725188
# 23    16.889915
# 24    -5.615070
# 25     2.176871
# 26    -3.793890
# ...

# %%
import pandas as pd
indices_atipicos = abs(y_pred_AD) > 200
ids_atipicos = df_AD_filtrado.loc[indices_atipicos, "ID-unique"]
print(f"IDs atípicos con predicciones > 200: {ids_atipicos.tolist()}")
df_AD_filtrado_sin_atipicos = df_AD_filtrado[~df_AD_filtrado["ID-unique"].isin(ids_atipicos)].reset_index(drop=True)
print(f"Nuevo tamaño del DataFrame filtrado: {df_AD_filtrado_sin_atipicos.shape}")
# Out:
# IDs atípicos con predicciones > 200: []
# Nuevo tamaño del DataFrame filtrado: (305, 232)

# %%
file_path_AD_2 = f'{path_}Brain_Aging/AD_freq_2.xlsx'
#df_AD_filtrado_sin_atipicos.to_excel(file_path_AD_2, index=False)

# %%
import pandas as pd
indices_atipicos = abs(y_pred_FTD) > 200
ids_atipicos = df_FTD_filtrado.loc[indices_atipicos, "ID-unique"]
print(f"IDs atípicos con predicciones > 200: {ids_atipicos.tolist()}")
df_FTD_filtrado_sin_atipicos = df_FTD_filtrado[~df_FTD_filtrado["ID-unique"].isin(ids_atipicos)].reset_index(drop=True)
print(f"Nuevo tamaño del DataFrame filtrado: {df_FTD_filtrado_sin_atipicos.shape}")
# Out:
# IDs atípicos con predicciones > 200: []
# Nuevo tamaño del DataFrame filtrado: (58, 232)

# %%
file_path_FTD_2 = f'{path_}Brain_Aging/FTD_freq_2.xlsx'
df_FTD_filtrado_sin_atipicos.to_excel(file_path_FTD_2, index=False)

# %%
import pandas as pd
indices_atipicos = abs(y_pred_MCI) > 200
ids_atipicos = df_MCI_filtrado.loc[indices_atipicos, "ID-unique"]
print(f"IDs atípicos con predicciones > 200: {ids_atipicos.tolist()}")
df_MCI_filtrado_sin_atipicos = df_MCI_filtrado[~df_MCI_filtrado["ID-unique"].isin(ids_atipicos)].reset_index(drop=True)
print(f"Nuevo tamaño del DataFrame filtrado: {df_MCI_filtrado_sin_atipicos.shape}")
# Out:
# IDs atípicos con predicciones > 200: []
# Nuevo tamaño del DataFrame filtrado: (228, 232)

# %%
file_path_MCI_2 = f'{path_}Brain_Aging/MCI_freq_2.xlsx'
df_MCI_filtrado_sin_atipicos.to_excel(file_path_MCI_2, index=False)

# %%
import pandas as pd
indices_atipicos = abs(y_pred_PD) > 200
ids_atipicos = df_PD_filtrado.loc[indices_atipicos, "ID-unique"]
print(f"IDs atípicos con predicciones > 200: {ids_atipicos.tolist()}")
df_PD_filtrado_sin_atipicos = df_PD_filtrado[~df_PD_filtrado["ID-unique"].isin(ids_atipicos)].reset_index(drop=True)
print(f"Nuevo tamaño del DataFrame filtrado: {df_PD_filtrado_sin_atipicos.shape}")
# Out:
# IDs atípicos con predicciones > 200: []
# Nuevo tamaño del DataFrame filtrado: (56, 233)

# %%
file_path_PD_2 = f'{path_}Brain_Aging/PD_freq_2.xlsx'
df_PD_filtrado_sin_atipicos.to_excel(file_path_PD_2, index=False)

# %% [markdown]
# # Prueba T-student

# %%
file_path_CN = f'{path_}Brain_Aging/CN_freq.xlsx'
file_path_AD = f'{path_}Brain_Aging/AD_freq.xlsx'
file_path_FTD = f'{path_}Brain_Aging/FTD_freq.xlsx'
file_path_MCI = f'{path_}Brain_Aging/MCI_freq.xlsx'
file_path_PD = f'{path_}Brain_Aging/PD_freq.xlsx'

# %%
df_CN = pd.read_excel(file_path_CN)
df_AD = pd.read_excel(file_path_AD)
df_FTD = pd.read_excel(file_path_FTD)
df_MCI = pd.read_excel(file_path_MCI)
df_PD = pd.read_excel(file_path_PD)

# %%
features=['Alpha2_canon_EPP_HPC_left', 'Alpha2_canon_EPP_HPC_right', 'Alpha2_canon_EPP_PARIET_left', 'Alpha2_canon_EPP_PARIET_right', 'Alpha2_canon_EPP_OCC_left', 'Alpha2_canon_EPP_OCC_right', 'Alpha2_canon_RPD_HPC_left', 'Alpha2_canon_RPD_HPC_right', 'Alpha2_canon_RPD_CING_left', 'Alpha2_canon_RPD_CING_right', 'Alpha2_canon_RPD_PARIET_left', 'Alpha2_canon_RPD_PARIET_right', 'Alpha2_canon_RPD_OCC_left', 'Alpha2_canon_RPD_OCC_right', 'High_subj_spec_EPP_HPC_left', 'High_subj_spec_EPP_HPC_right', 'High_subj_spec_EPP_CING_left', 'High_subj_spec_EPP_CING_right', 'High_subj_spec_EPP_PARIET_left', 'High_subj_spec_EPP_PARIET_right', 'High_subj_spec_EPP_OCC_left', 'High_subj_spec_EPP_OCC_right', 'High_subj_spec_RPD_HPC_left', 'High_subj_spec_RPD_HPC_right', 'High_subj_spec_RPD_CING_left', 'High_subj_spec_RPD_CING_right', 'High_subj_spec_RPD_PARIET_left', 'High_subj_spec_RPD_PARIET_right', 'High_subj_spec_RPD_OCC_left', 'High_subj_spec_RPD_OCC_right', 'Low_subj_spec_EPP_HPC_left', 'Low_subj_spec_EPP_HPC_right', 'Low_subj_spec_EPP_CING_left', 'Low_subj_spec_EPP_CING_right', 'Low_subj_spec_EPP_PARIET_left', 'Low_subj_spec_EPP_PARIET_right', 'Low_subj_spec_EPP_OCC_left', 'Low_subj_spec_EPP_OCC_right', 'Low_subj_spec_RPD_HPC_left', 'Low_subj_spec_RPD_HPC_right', 'Low_subj_spec_RPD_CING_left', 'Low_subj_spec_RPD_CING_right', 'Low_subj_spec_RPD_PARIET_left', 'Low_subj_spec_RPD_PARIET_right', 'Low_subj_spec_RPD_OCC_left', 'Low_subj_spec_RPD_OCC_right', 'TF_ORB_left', 'TF_ORB_right', 'TF_IFG_left', 'TF_IFG_right', 'TF_MFG_left', 'TF_MFG_right', 'TF_SFG_left', 'TF_SFG_right', 'TF_HPC_left', 'TF_HPC_right', 'TF_INS_left', 'TF_INS_right', 'IAF_ORB_left', 'IAF_ORB_right', 'IAF_IFG_left', 'IAF_IFG_right', 'IAF_MFG_left', 'IAF_MFG_right', 'IAF_SFG_left', 'IAF_SFG_right', 'IAF_HPC_left', 'IAF_HPC_right', 'IAF_INS_left', 'IAF_INS_right', 'IAF_OCC_left', 'IAF_OCC_right']

# %%
len(features)
# Out:
# 72

# %%
df_CN_filtrado = df_CN[(df_CN['Age'] >= 50) & (df_CN['Age'] <= 80)].reset_index(drop=True)
df_AD_filtrado = df_AD[(df_AD['Age'] >= 50) & (df_AD['Age'] <= 80)].reset_index(drop=True)
df_FTD_filtrado = df_FTD[(df_FTD['Age'] >= 50) & (df_FTD['Age'] <= 80)].reset_index(drop=True)
df_MCI_filtrado = df_MCI[(df_MCI['Age'] >= 50) & (df_MCI['Age'] <=80)].reset_index(drop=True)
df_PD_filtrado = df_PD[(df_PD['Age'] >= 50) & (df_PD['Age'] <= 80)].reset_index(drop=True)

# %%
X_CN = df_CN_filtrado[features]
X_AD = df_AD_filtrado[features]
X_MCI = df_MCI_filtrado[features]
X_FTD = df_FTD_filtrado[features]
X_PD = df_PD_filtrado[features]

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

X_combined = pd.concat([X_CN, X_AD, X_FTD, X_MCI, X_PD], axis=0).reset_index(drop=True)
#X_combined = pd.concat([X_CN, X_AD], axis=0).reset_index(drop=True)
scaler = MinMaxScaler()
scaler.fit(X_combined)

X_CN_scaled = scaler.transform(X_CN)
X_AD_scaled = scaler.transform(X_AD)
X_FTD_scaled = scaler.transform(X_FTD)
X_MCI_scaled = scaler.transform(X_MCI)
X_PD_scaled = scaler.transform(X_PD)

X_CN_scaled = pd.DataFrame(X_CN_scaled, columns=X_CN.columns)
X_AD_scaled = pd.DataFrame(X_AD_scaled, columns=X_AD.columns)
X_FTD_scaled = pd.DataFrame(X_FTD_scaled, columns=X_FTD.columns)
X_MCI_scaled = pd.DataFrame(X_MCI_scaled, columns=X_MCI.columns)
X_PD_scaled = pd.DataFrame(X_PD_scaled, columns=X_PD.columns)

# %%
import pandas as pd
from scipy import stats

t_statistics = []
p_values = []
for col in X_AD_scaled.columns:
    t_stat, p_val = stats.ttest_ind(X_AD_scaled[col], X_CN_scaled[col], equal_var=False)
    
    t_statistics.append(t_stat)
    p_values.append(p_val)

results = pd.DataFrame({
    'Feature': X_AD_scaled.columns,
    'T-Statistic': t_statistics,
    'P-Value': p_values
})

print(results)
# Out:
#                           Feature  T-Statistic       P-Value
# 0       Alpha2_canon_EPP_HPC_left     4.172067  3.548412e-05
# 1      Alpha2_canon_EPP_HPC_right     4.192820  3.356532e-05
# 2    Alpha2_canon_EPP_PARIET_left     6.623732  9.827798e-11
# 3   Alpha2_canon_EPP_PARIET_right     7.607405  1.575720e-13
# 4       Alpha2_canon_EPP_OCC_left     4.786947  2.183167e-06
# ..                            ...          ...           ...
# 67                  IAF_HPC_right    -2.398517  1.689852e-02
# 68                   IAF_INS_left    -1.955426  5.118345e-02
# 69                  IAF_INS_right    -0.812252  4.171267e-01
# 70                   IAF_OCC_left    -6.151492  1.724176e-09
# 71                  IAF_OCC_right    -6.943703  1.196596e-11
#
# [72 rows x 3 columns]

# %%
significant_features = results[results['P-Value'] < 0.05]['Feature'].tolist()
print(significant_features)
# Out:
# ['Alpha2_canon_EPP_HPC_left', 'Alpha2_canon_EPP_HPC_right', 'Alpha2_canon_EPP_PARIET_left', 'Alpha2_canon_EPP_PARIET_right', 'Alpha2_canon_EPP_OCC_left', 'Alpha2_canon_EPP_OCC_right', 'Alpha2_canon_RPD_HPC_left', 'Alpha2_canon_RPD_HPC_right', 'Alpha2_canon_RPD_CING_left', 'Alpha2_canon_RPD_CING_right', 'Alpha2_canon_RPD_PARIET_left', 'Alpha2_canon_RPD_PARIET_right', 'Alpha2_canon_RPD_OCC_left', 'Alpha2_canon_RPD_OCC_right', 'High_subj_spec_EPP_HPC_left', 'High_subj_spec_EPP_HPC_right', 'High_subj_spec_EPP_CING_left', 'High_subj_spec_EPP_CING_right', 'High_subj_spec_EPP_PARIET_left', 'High_subj_spec_EPP_PARIET_right', 'High_subj_spec_EPP_OCC_left', 'High_subj_spec_EPP_OCC_right', 'High_subj_spec_RPD_HPC_left', 'High_subj_spec_RPD_HPC_right', 'High_subj_spec_RPD_CING_left', 'High_subj_spec_RPD_CING_right', 'High_subj_spec_RPD_PARIET_left', 'High_subj_spec_RPD_PARIET_right', 'High_subj_spec_RPD_OCC_left', 'High_subj_spec_RPD_OCC_right', 'Low_subj_spec_EPP_HPC_left', 'Low_subj_spec_EPP_H
# ...

# %%
len(significant_features)
# Out:
# 59

# %% [markdown]
# # Analisis datos malos

# %%
import pandas as pd
path_ = r'C:/Users/felipe/Documents/Brain/'
file_path_CN = f'{path_}Brain_Aging/CN_freq.xlsx'
file_path_AD = f'{path_}Brain_Aging/AD_freq.xlsx'
file_path_FTD = f'{path_}Brain_Aging/FTD_freq.xlsx'
file_path_MCI = f'{path_}Brain_Aging/MCI_freq.xlsx'
file_path_PD = f'{path_}Brain_Aging/PD_freq.xlsx'

df_CN = pd.read_excel(file_path_CN)
df_AD = pd.read_excel(file_path_AD)
df_FTD = pd.read_excel(file_path_FTD)
df_MCI = pd.read_excel(file_path_MCI)
df_PD = pd.read_excel(file_path_PD)

# %%
df_CN_filtrado = df_CN[(df_CN['Age'] >= 40) & (df_CN['Age'] <= 90)].reset_index(drop=True)
df_AD_filtrado = df_AD[(df_AD['Age'] >= 40) & (df_AD['Age'] <= 90)].reset_index(drop=True)
df_FTD_filtrado = df_FTD[(df_FTD['Age'] >= 40) & (df_FTD['Age'] <= 90)].reset_index(drop=True)
df_MCI_filtrado = df_MCI[(df_MCI['Age'] >= 40) & (df_MCI['Age'] <= 90)].reset_index(drop=True)
df_PD_filtrado = df_PD[(df_PD['Age'] >= 40) & (df_PD['Age'] <= 90)].reset_index(drop=True)

# %%
significant_features=['Alpha2_canon_EPP_HPC_left', 'Alpha2_canon_EPP_HPC_right', 'Alpha2_canon_EPP_PARIET_left', 'Alpha2_canon_EPP_PARIET_right', 'Alpha2_canon_EPP_OCC_left', 'Alpha2_canon_EPP_OCC_right', 'Alpha2_canon_RPD_HPC_left', 'Alpha2_canon_RPD_HPC_right', 'Alpha2_canon_RPD_CING_left', 'Alpha2_canon_RPD_CING_right', 'Alpha2_canon_RPD_PARIET_left', 'Alpha2_canon_RPD_PARIET_right', 'Alpha2_canon_RPD_OCC_left', 'Alpha2_canon_RPD_OCC_right', 'High_subj_spec_EPP_HPC_left', 'High_subj_spec_EPP_HPC_right', 'High_subj_spec_EPP_CING_left', 'High_subj_spec_EPP_CING_right', 'High_subj_spec_EPP_PARIET_left', 'High_subj_spec_EPP_PARIET_right', 'High_subj_spec_EPP_OCC_left', 'High_subj_spec_EPP_OCC_right', 'High_subj_spec_RPD_HPC_left', 'High_subj_spec_RPD_HPC_right', 'High_subj_spec_RPD_CING_left', 'High_subj_spec_RPD_CING_right', 'High_subj_spec_RPD_PARIET_left', 'High_subj_spec_RPD_PARIET_right', 'High_subj_spec_RPD_OCC_left', 'High_subj_spec_RPD_OCC_right', 'Low_subj_spec_EPP_HPC_left', 'Low_subj_spec_EPP_HPC_right', 'Low_subj_spec_EPP_CING_left', 'Low_subj_spec_EPP_CING_right', 'Low_subj_spec_EPP_PARIET_left', 'Low_subj_spec_EPP_PARIET_right', 'Low_subj_spec_EPP_OCC_left', 'Low_subj_spec_EPP_OCC_right', 'Low_subj_spec_RPD_HPC_left', 'Low_subj_spec_RPD_HPC_right', 'Low_subj_spec_RPD_CING_left', 'Low_subj_spec_RPD_CING_right', 'Low_subj_spec_RPD_PARIET_left', 'Low_subj_spec_RPD_PARIET_right', 'Low_subj_spec_RPD_OCC_left', 'Low_subj_spec_RPD_OCC_right', 'TF_ORB_left', 'TF_ORB_right', 'TF_IFG_left', 'TF_IFG_right', 'TF_MFG_left', 'TF_MFG_right', 'TF_SFG_left', 'TF_SFG_right', 'TF_HPC_left', 'TF_HPC_right', 'TF_INS_left', 'TF_INS_right', 'IAF_ORB_left', 'IAF_ORB_right', 'IAF_IFG_left', 'IAF_IFG_right', 'IAF_MFG_left', 'IAF_MFG_right', 'IAF_SFG_left', 'IAF_SFG_right', 'IAF_HPC_left', 'IAF_HPC_right', 'IAF_INS_left', 'IAF_INS_right', 'IAF_OCC_left', 'IAF_OCC_right']

# %%
len(significant_features)
# Out:
# 72

# %%
significant_features=['Alpha2_canon_EPP_HPC_left', 'Alpha2_canon_EPP_HPC_right', 'Alpha2_canon_EPP_PARIET_left', 'Alpha2_canon_EPP_OCC_left', 'Alpha2_canon_RPD_HPC_left', 'Alpha2_canon_RPD_HPC_right', 'Alpha2_canon_RPD_CING_left', 'Alpha2_canon_RPD_CING_right', 'Alpha2_canon_RPD_PARIET_left', 'Alpha2_canon_RPD_OCC_left', 'High_subj_spec_EPP_HPC_left', 'High_subj_spec_EPP_HPC_right', 'High_subj_spec_EPP_CING_left', 'High_subj_spec_EPP_CING_right', 'High_subj_spec_EPP_PARIET_left', 'High_subj_spec_EPP_PARIET_right', 'High_subj_spec_EPP_OCC_left', 'High_subj_spec_EPP_OCC_right', 'High_subj_spec_RPD_HPC_left', 'High_subj_spec_RPD_HPC_right', 'High_subj_spec_RPD_CING_left', 'High_subj_spec_RPD_CING_right', 'High_subj_spec_RPD_PARIET_left', 'High_subj_spec_RPD_PARIET_right', 'High_subj_spec_RPD_OCC_left', 'High_subj_spec_RPD_OCC_right', 'Low_subj_spec_EPP_HPC_right', 'Low_subj_spec_EPP_CING_left', 'Low_subj_spec_EPP_CING_right',  'Low_subj_spec_EPP_PARIET_right', 'Low_subj_spec_EPP_OCC_left', 'Low_subj_spec_EPP_OCC_right', 'Low_subj_spec_RPD_HPC_left', 'Low_subj_spec_RPD_HPC_right', 'Low_subj_spec_RPD_CING_left', 'Low_subj_spec_RPD_CING_right', 'Low_subj_spec_RPD_PARIET_left', 'Low_subj_spec_RPD_PARIET_right', 'Low_subj_spec_RPD_OCC_left', 'Low_subj_spec_RPD_OCC_right',  'TF_IFG_right', 'TF_MFG_right', 'TF_SFG_left', 'TF_SFG_right', 'TF_HPC_left', 'TF_HPC_right', 'TF_INS_left', 'TF_INS_right', 'IAF_ORB_left', 'IAF_IFG_left', 'IAF_IFG_right', 'IAF_MFG_left', 'IAF_MFG_right', 'IAF_SFG_left', 'IAF_SFG_right', 'IAF_HPC_right', 'IAF_INS_left', 'IAF_INS_right', 'IAF_OCC_left', 'IAF_OCC_right']

# %%
len(significant_features)
# Out:
# 60

# %%
X_CN = df_CN_filtrado[significant_features]
y_CN = df_CN_filtrado["Age"]
ID_CN = df_CN_filtrado["ID-unique"]

X_AD = df_AD_filtrado[significant_features]
y_AD = df_AD_filtrado["Age"]
ID_AD = df_AD_filtrado["ID-unique"]

X_FTD = df_FTD_filtrado[significant_features]
y_FTD = df_FTD_filtrado["Age"]
ID_FTD = df_FTD_filtrado["ID-unique"]

X_MCI = df_MCI_filtrado[significant_features]
y_MCI = df_MCI_filtrado["Age"]
ID_MCI = df_MCI_filtrado["ID-unique"]

X_PD = df_PD_filtrado[significant_features]
y_PD = df_PD_filtrado["Age"]
ID_PD = df_PD_filtrado["ID-unique"]

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import pandas as pd

# Lista de índices outliers basados en ID-unique
outliers_ids = [161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199]

# Dividir los datos en dos conjuntos basados en la lista de outliers
X_AD_1 = df_AD_filtrado[~df_AD_filtrado['ID-unique'].isin(outliers_ids)][significant_features]
X_AD_2 = df_AD_filtrado[df_AD_filtrado['ID-unique'].isin(outliers_ids)][significant_features]

y_AD_1 = df_AD_filtrado[~df_AD_filtrado['ID-unique'].isin(outliers_ids)]['Age']
y_AD_2 = df_AD_filtrado[df_AD_filtrado['ID-unique'].isin(outliers_ids)]['Age']

# Escalar los datos
scaler = StandardScaler()

scaler.fit(X_AD_1)

X_AD_1_scaled = scaler.transform(X_AD_1)
X_AD_2_scaled = scaler.transform(X_AD_2)

X_AD_1_scaled = pd.DataFrame(X_AD_1_scaled, columns=X_AD_1.columns)
X_AD_2_scaled = pd.DataFrame(X_AD_2_scaled, columns=X_AD_2.columns)

# Convertir y en DataFrames
#y_AD_1 = pd.DataFrame(y_AD_1).reset_index(drop=True)
#y_AD_2 = pd.DataFrame(y_AD_2).reset_index(drop=True)

print(f"X_AD_1 shape: {X_AD_1.shape}")
print(f"X_AD_2 shape: {X_AD_2.shape}")
print(f"y_AD_1 shape: {y_AD_1.shape}")
print(f"y_AD_2 shape: {y_AD_2.shape}")
# Out:
# X_AD_1 shape: (266, 60)
# X_AD_2 shape: (39, 60)
# y_AD_1 shape: (266,)
# y_AD_2 shape: (39,)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Crear una figura con tres subplots (uno para cada tipo de escalamiento y el original)
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 13), sharey=True)

# Configurar el estilo de seaborn
sns.set(style="whitegrid")

# Crear el diagrama de caja y bigotes para el dataframe original
sns.boxplot(data=X_AD_1_scaled, palette='Set2', orient='h', ax=axs[0])
axs[0].set_title('AD sin outliers', fontsize=16, fontweight='bold')
axs[0].set_xlabel('Valores', fontsize=14, fontweight='bold')
axs[0].set_ylabel('Características', fontsize=18, fontweight='bold')
axs[0].tick_params(axis='x', labelsize=14)
axs[0].tick_params(axis='y', labelsize=12)
axs[0].tick_params(axis='x', which='major', width=2)

# Fijar el límite del eje x para el primer gráfico
axs[0].set_xlim(-2, 5)

# Crear el diagrama de caja y bigotes para MinMaxScaler
sns.boxplot(data=X_AD_2_scaled, palette='Set2', orient='h', ax=axs[1])
axs[1].set_title('AD outliers', fontsize=16, fontweight='bold')
axs[1].set_xlabel('Valores', fontsize=14, fontweight='bold')
axs[1].set_ylabel('')  # No se necesita establecer la etiqueta y en el segundo gráfico
axs[1].tick_params(axis='x', labelsize=14)
axs[1].tick_params(axis='y', labelsize=8)
axs[1].tick_params(axis='x', which='major', width=2)

# Fijar el límite del eje x para el segundo gráfico
axs[1].set_xlim(-2, 5)

# Ajustar el espacio entre subplots
plt.tight_layout()

# Mostrar el diagrama
plt.show()

# %%
from scipy.stats import mannwhitneyu

p_values = []

for column in X_AD_1.columns:
    # Realizar la prueba de Mann-Whitney U para cada característica
    stat, p_value = mannwhitneyu(X_AD_1[column], X_AD_2[column])
    p_values.append((column, p_value))

# Convertir los resultados en un DataFrame
import pandas as pd
p_values_df = pd.DataFrame(p_values, columns=['Característica', 'P-valor'])

# Mostrar las características con p-valores menores a 0.05 (significancia estadística)
significant_features_mannwhitneyu = p_values_df[p_values_df['P-valor'] < 0.05]
print("Características significativamente diferentes entre X_AD_1 y X_AD_2:")
print(significant_features_mannwhitneyu)
# Out:
# Características significativamente diferentes entre X_AD_1 y X_AD_2:
# Empty DataFrame
# Columns: [Característica, P-valor]
# Index: []

# %%
from scipy.stats import ttest_ind
import pandas as pd

p_values = []

for column in X_AD_1.columns:
    # Realizar la prueba t de Student para cada característica
    stat, p_value = ttest_ind(X_AD_1[column], X_AD_2[column], equal_var=True)  
    p_values.append((column, p_value))

# Convertir los resultados en un DataFrame
p_values_df = pd.DataFrame(p_values, columns=['Característica', 'P-valor'])

# Mostrar las características con p-valores menores a 0.05 (significancia estadística)
significant_features_ttest_ind = p_values_df[p_values_df['P-valor'] < 0.05]
print("Características significativamente diferentes entre X_AD_1 y X_AD_2:")
print(significant_features_ttest_ind)
# Out:
# Características significativamente diferentes entre X_AD_1 y X_AD_2:
# Empty DataFrame
# Columns: [Característica, P-valor]
# Index: []

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Asegúrate de que significant_features esté definido
# Filtrar las características significativas
significant_columns = significant_features_ttest_ind['Característica']

# Crear una figura para los boxplots
plt.figure(figsize=(15, 20))

# Iterar a través de las características significativas y crear un boxplot para cada una
for i, column in enumerate(significant_columns):
    plt.subplot(len(significant_columns), 1, i + 1)
    # Crear un DataFrame combinado con las dos muestras
    combined_df = pd.DataFrame({
        'Valor': pd.concat([X_AD_1[column], X_AD_2[column]]),
        'Grupo': ['X_AD_1'] * len(X_AD_1[column]) + ['X_AD_2'] * len(X_AD_2[column])
    })
    # Crear el boxplot horizontal
    sns.boxplot(x='Valor', y='Grupo', data=combined_df)
    plt.title(f'{column}', fontsize=16)
    plt.xlabel('Valor')
    plt.ylabel('Grupo')

# Ajustar el diseño para evitar solapamiento
plt.tight_layout()
plt.show()

# %%
# Calcular la media de cada característica en ambos conjuntos
mean_diff = X_AD_1.mean() - X_AD_2.mean()

# Ordenar las características por la mayor diferencia absoluta en la media
mean_diff_sorted = mean_diff.abs().sort_values(ascending=False)
print("Características con mayores diferencias en las medias:")
print(mean_diff_sorted.head(10))
# Out:
# Características con mayores diferencias en las medias:
# IAF_MFG_right    0.365565
# IAF_MFG_left     0.310572
# IAF_IFG_right    0.300069
# IAF_SFG_left     0.291932
# IAF_IFG_left     0.267102
# IAF_ORB_left     0.257246
# IAF_HPC_right    0.215812
# IAF_OCC_left     0.187295
# IAF_SFG_right    0.157690
# IAF_INS_left     0.157365
# dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import Ridge, Lasso

scaler = MinMaxScaler((0.05,0.95))
#scaler = StandardScaler()

scaler.fit(X_CN)

X_CN_scaled = scaler.transform(X_CN)
X_AD_scaled_1 = scaler.transform(X_AD_1)
X_AD_scaled_2 = scaler.transform(X_AD_2)
X_FTD_scaled = scaler.transform(X_FTD)
X_MCI_scaled = scaler.transform(X_MCI)
X_PD_scaled = scaler.transform(X_PD)

X_CN_train, X_CN_test, y_CN_train, y_CN_test = train_test_split(X_CN_scaled, y_CN, test_size=0.2, random_state=42)

##################################
#model = LinearRegression()
#model.fit(X_CN_train, y_CN_train)

#model = Ridge(alpha=1.0)
#model.fit(X_CN_train, y_CN_train)

model = Lasso(alpha=0.1)
model.fit(X_CN_train, y_CN_train)


############################3
y_pred_CN_test = model.predict(X_CN_test)

mse_CN_test = mean_squared_error(y_CN_test, y_pred_CN_test)
r2_CN_test = r2_score(y_CN_test, y_pred_CN_test)
print(f"Resultados en CN (test): MSE = {mse_CN_test}, R2 = {r2_CN_test}")


##########
y_pred_AD_1 = model.predict(X_AD_scaled_1)

mse_AD_1 = mean_squared_error(y_AD_1, y_pred_AD_1)
r2_AD_1 = r2_score(y_AD_1, y_pred_AD_1)
print(f"Resultados en AD_1: MSE = {mse_AD_1}, R2 = {r2_AD_1}")

residuals_AD_1 = y_AD_1 - y_pred_AD_1  # Calcular los residuales (errores)
print(f"Residuals en AD_1: {residuals_AD_1}")

#####
y_pred_AD_2 = model.predict(X_AD_scaled_2)

mse_AD_2 = mean_squared_error(y_AD_2, y_pred_AD_2)
r2_AD_2 = r2_score(y_AD_2, y_pred_AD_2)
print(f"Resultados en AD_2: MSE = {mse_AD_2}, R2 = {r2_AD_2}")

residuals_AD_2 = y_AD_2 - y_pred_AD_2  # Calcular los residuales (errores)
print(f"Residuals en AD_2: {residuals_AD_2}")


#######
# Para FTD
y_pred_FTD = model.predict(X_FTD_scaled)

mse_FTD = mean_squared_error(y_FTD, y_pred_FTD)
r2_FTD = r2_score(y_FTD, y_pred_FTD)
print(f"Resultados en FTD: MSE = {mse_FTD}, R2 = {r2_FTD}")

residuals_FTD = y_FTD - y_pred_FTD  # Calcular los residuales (errores)
print(f"Residuals en FTD: {residuals_FTD}")

# Para MCI
y_pred_MCI = model.predict(X_MCI_scaled)

mse_MCI = mean_squared_error(y_MCI, y_pred_MCI)
r2_MCI = r2_score(y_MCI, y_pred_MCI)
print(f"Resultados en MCI: MSE = {mse_MCI}, R2 = {r2_MCI}")

residuals_MCI = y_MCI - y_pred_MCI  # Calcular los residuales (errores)
print(f"Residuals en MCI: {residuals_MCI}")

# Para PD
y_pred_PD = model.predict(X_PD_scaled)

mse_PD = mean_squared_error(y_PD, y_pred_PD)
r2_PD = r2_score(y_PD, y_pred_PD)
print(f"Resultados en PD: MSE = {mse_PD}, R2 = {r2_PD}")

residuals_PD = y_PD - y_pred_PD  # Calcular los residuales (errores)
print(f"Residuals en PD: {residuals_PD}")
# Out:
# Resultados en CN (test): MSE = 101.38914102314257, R2 = 0.0036746157337028684
# Resultados en AD_1: MSE = 160.19795945810122, R2 = -2.340022282424215
# Residuals en AD_1: 0       7.365125
# 1       8.189325
# 2      25.517685
# 3       9.474395
# 4       6.727715
#          ...
# 300    10.975350
# 301     6.444013
# 302     9.140015
# 303     3.230263
# 304    17.361883
# Name: Age, Length: 266, dtype: float64
# Resultados en AD_2: MSE = 82.62082669443116, R2 = -0.5812648153089115
# Residuals en AD_2: 155    -1.638534
# 156    14.805207
# 157    13.568119
# 158    13.990264
# 159     8.098766
# 160    -6.290501
# 161    17.675109
# 162     8.380111
# 163     9.411790
# 164     0.300679
# 165     9.458480
# 166    -8.679055
# 167     7.197075
# 168    12.723934
# 169    -4.191127
# 170     0.579540
# 171     9.138138
# 172     3.345683
# 173     5.938822
# 174    15.742975
# 175     3.790419
# 176     8.711638
# 177     9.564584
# 178    -1.743121
# 179    -5.497274
# ...

# %%
# Obtener los coeficientes
coeficientes = model.coef_

# Si también tienes un término independiente (intercepto), puedes obtenerlo con:
intercepto = model.intercept_

print("Coeficientes:", coeficientes)
print("Intercepto:", intercepto)
# Out:
# Coeficientes: [ -6.10013557   3.38180502   3.97622423  -0.85534739  -6.10013557
#    3.38180502   6.62156783  -2.82627479   3.97622423  -0.85534739
#   -0.34851534  -1.7202861    7.00393425  -7.83180154  -3.54419808
#    1.91846834  -2.0073844    0.60879439  -0.34851534  -1.7202861
#    7.00393425  -7.83180154  -3.54419808   1.91846834  -2.0073844
#    0.60879439  -0.80147597   0.55494436   0.2635184   -9.12484092
#  -11.4845149   -2.00149053   3.43670203   1.87168428   7.60805632
#   -6.99745502  -6.59318063   6.55363251   3.30602129   3.80915282
#    1.90148715   2.96458511  -0.32463397  -2.14919146   0.86461045
#   -0.58191175  -2.47300933  -0.6125753    3.10656291  -0.17476125
#    0.40001394  -2.31931814  -3.15988721   4.00174076   6.28245101
#   -0.83899409  -4.85559456  -4.35069493  -0.39174238   1.02266934]
# Intercepto: 67.5241476921367

# %%
X_AD_scaled_1 = pd.DataFrame(X_AD_scaled_1, columns=X_AD_1.columns)
X_AD_scaled_2 = pd.DataFrame(X_AD_scaled_2, columns=X_AD_2.columns)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Crear una figura con tres subplots (uno para cada tipo de escalamiento y el original)
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 13), sharey=True)

# Configurar el estilo de seaborn
sns.set(style="whitegrid")

# Crear el diagrama de caja y bigotes para el dataframe original
sns.boxplot(data=X_AD_scaled_1, palette='Set2', orient='h', ax=axs[0])
axs[0].set_title('AD sin outliers', fontsize=16, fontweight='bold')
axs[0].set_xlabel('Valores', fontsize=14, fontweight='bold')
axs[0].set_ylabel('Características', fontsize=18, fontweight='bold')
axs[0].tick_params(axis='x', labelsize=14)
axs[0].tick_params(axis='y', labelsize=12)
axs[0].tick_params(axis='x', which='major', width=2)

# Fijar el límite del eje x para el primer gráfico
axs[0].set_xlim(0, 1)

# Crear el diagrama de caja y bigotes para MinMaxScaler
sns.boxplot(data=X_AD_scaled_2, palette='Set2', orient='h', ax=axs[1])
axs[1].set_title('AD outliers', fontsize=16, fontweight='bold')
axs[1].set_xlabel('Valores', fontsize=14, fontweight='bold')
axs[1].set_ylabel('')  # No se necesita establecer la etiqueta y en el segundo gráfico
axs[1].tick_params(axis='x', labelsize=14)
axs[1].tick_params(axis='y', labelsize=8)
axs[1].tick_params(axis='x', which='major', width=2)

# Fijar el límite del eje x para el segundo gráfico
axs[1].set_xlim(0, 1)

# Ajustar el espacio entre subplots
plt.tight_layout()

# Mostrar el diagrama
plt.show()

# %%
from scipy.stats import ttest_ind
import pandas as pd

p_values = []

for column in X_AD_scaled_1.columns:
    # Realizar la prueba t de Student para cada característica
    stat, p_value = ttest_ind(X_AD_scaled_1[column], X_AD_scaled_2[column], equal_var=True)  
    p_values.append((column, p_value))

# Convertir los resultados en un DataFrame
p_values_df = pd.DataFrame(p_values, columns=['Característica', 'P-valor'])

# Mostrar las características con p-valores menores a 0.05 (significancia estadística)
significant_features_ = p_values_df[p_values_df['P-valor'] > 0.05]
print("Características significativamente diferentes entre X_AD_1 y X_AD_2:")
print(significant_features_)
# Out:
# Características significativamente diferentes entre X_AD_1 y X_AD_2:
#                   Característica   P-valor
# 0      Alpha2_canon_EPP_HPC_left  0.816491
# 1     Alpha2_canon_EPP_HPC_right  0.598550
# 2   Alpha2_canon_EPP_PARIET_left  0.419889
# 4      Alpha2_canon_EPP_OCC_left  0.106245
# 6      Alpha2_canon_RPD_HPC_left  0.816490
# ..                           ...       ...
# 67                 IAF_HPC_right  0.289437
# 68                  IAF_INS_left  0.482782
# 69                 IAF_INS_right  0.737331
# 70                  IAF_OCC_left  0.190389
# 71                 IAF_OCC_right  0.320068
#
# [62 rows x 2 columns]

# %%
significant_features_['Característica'].tolist()
# Out:
# ['Alpha2_canon_EPP_HPC_left',
#  'Alpha2_canon_EPP_HPC_right',
#  'Alpha2_canon_EPP_PARIET_left',
#  'Alpha2_canon_EPP_OCC_left',
#  'Alpha2_canon_RPD_HPC_left',
#  'Alpha2_canon_RPD_HPC_right',
#  'Alpha2_canon_RPD_CING_left',
#  'Alpha2_canon_RPD_CING_right',
#  'Alpha2_canon_RPD_PARIET_left',
#  'Alpha2_canon_RPD_OCC_left',
#  'High_subj_spec_EPP_HPC_left',
#  'High_subj_spec_EPP_HPC_right',
#  'High_subj_spec_EPP_CING_left',
#  'High_subj_spec_EPP_CING_right',
#  'High_subj_spec_EPP_PARIET_left',
#  'High_subj_spec_EPP_PARIET_right',
#  'High_subj_spec_EPP_OCC_left',
#  'High_subj_spec_EPP_OCC_right',
#  'High_subj_spec_RPD_HPC_left',
#  'High_subj_spec_RPD_HPC_right',
#  'High_subj_spec_RPD_CING_left',
#  'High_subj_spec_RPD_CING_right',
#  'High_subj_spec_RPD_PARIET_left',
#  'High_subj_spec_RPD_PARIET_right',
#  'High_subj_spec_RPD_OCC_left',
#  'High_subj_spec_RPD_OCC_right',
#  'Low_subj_spec_EPP_HPC_right',
#  'Low_subj_spec_EPP_CING_left',
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Asegúrate de que significant_features esté definido
# Filtrar las características significativas
significant_columns = significant_features_['Característica']

# Crear una figura para los boxplots
plt.figure(figsize=(15, 20))

# Iterar a través de las características significativas y crear un boxplot para cada una
for i, column in enumerate(significant_columns):
    plt.subplot(len(significant_columns), 1, i + 1)
    # Crear un DataFrame combinado con las dos muestras
    combined_df = pd.DataFrame({
        'Valor': pd.concat([X_AD_scaled_1[column], X_AD_scaled_2[column]]),
        'Grupo': ['X_AD_1'] * len(X_AD_scaled_1[column]) + ['X_AD_2'] * len(X_AD_scaled_2[column])
    })
    # Crear el boxplot horizontal
    sns.boxplot(x='Valor', y='Grupo', data=combined_df)
    plt.title(f'{column}', fontsize=16)
    plt.xlabel('Valor')
    plt.ylabel('Grupo')

# Ajustar el diseño para evitar solapamiento
plt.tight_layout()
plt.show()

# %%
X_AD_2

# %%
import pandas as pd


# Verificar si hay valores nulos en cada columna
nulos_por_columna = X_AD_2.isnull().sum()

# Verificar si hay alguna columna con valores nulos
hay_nulos = nulos_por_columna.any()

# Mostrar el número de valores nulos por columna
print("Número de valores nulos por columna:")
print(nulos_por_columna)

# Verificar si hay alguna columna con valores nulos
if hay_nulos:
    print("Hay valores nulos en alguna columna.")
else:
    print("No hay valores nulos en ninguna columna.")
# Out:
# Número de valores nulos por columna:
# Alpha2_canon_EPP_HPC_left        0
# Alpha2_canon_EPP_HPC_right       0
# Alpha2_canon_EPP_PARIET_left     0
# Alpha2_canon_EPP_PARIET_right    0
# Alpha2_canon_EPP_OCC_left        0
#                                 ..
# IAF_HPC_right                    0
# IAF_INS_left                     0
# IAF_INS_right                    0
# IAF_OCC_left                     0
# IAF_OCC_right                    0
# Length: 72, dtype: int64
# No hay valores nulos en ninguna columna.
